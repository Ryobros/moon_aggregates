# %%
import matplotlib.pyplot as plt

# Plot hasil filter
ax = kab_bandung.plot(figsize=(10, 6), color='darkgreen', edgecolor='white')
plt.title(f"Peta batas wilayah desa/kelurahan Kabupaten {kab_bandung['WADMKK'].iloc[0]}")
plt.show()
